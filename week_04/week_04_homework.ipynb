# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import statistics

csci_survey = "CSCI_Fall_2024_survey.csv"
df_csci = pd.read_csv(csci_survey)

df_csci
# Out:
#                     Timestamp What is your name?  \
# 0   2024/09/05 6:10:09 PM EST               Alex
# 1   2024/09/05 6:33:51 PM EST              Tanay
# 2   2024/09/05 6:34:21 PM EST            Akshita
# 3   2024/09/05 6:35:03 PM EST            Anthony
# 4   2024/09/05 6:35:56 PM EST               Nuri
# 5   2024/09/05 6:35:57 PM EST             Mahley
# 6   2024/09/05 6:36:02 PM EST             Chetan
# 7   2024/09/05 6:36:13 PM EST             Steven
# 8   2024/09/05 6:36:14 PM EST               Nico
# 9   2024/09/05 6:36:24 PM EST             Iovane
# 10  2024/09/05 6:36:36 PM EST            Brandon
# 11  2024/09/05 6:36:48 PM EST             Carter
# 12  2024/09/05 6:37:04 PM EST              Tanav
# 13  2024/09/05 6:37:23 PM EST           Abhishek
# 14  2024/09/05 6:37:32 PM EST              Garlo
# 15  2024/09/05 6:37:33 PM EST              Vivek
# 16  2024/09/05 6:37:43 PM EST          Abhilasha
# 17  2024/09/05 6:38:14 PM EST               Tony
# ...

# %%
df_csci["What state/country were you born in?"].value_counts()
# Out:
# What state/country were you born in?
# Missouri                               5
# St. Louis MO                           2
# Mexico                                 1
# Kansas, Overland Park                  1
# TEXAS                                  1
# Cameroon                               1
# india                                  1
# People's Republic of China             1
# I was born in Chandigarh, India!       1
# Oklahoma                               1
# United States Missouri                 1
# st.louis mo                            1
# Saint Louis, Missouri                  1
# New Jersey                             1
# Georgia (the country not the state)    1
# Missouri, USA                          1
# India                                  1
# st. louis, mo                          1
# Wisconsin                              1
# Frankfurt, Germany                     1
# Kazakhstah                             1
# Name: count, dtype: int64

# %%
import pandas as pd


df_csci["What state/country were you born in?"] = np.where(df_csci["What state/country were you born in?"] == "St.Louis MO", "Missouri",
np.where(df_csci["What state/country were you born in?"] == "st.louis mo", "Missouri",
np.where(df_csci["What state/country were you born in?"] == "Missouri", "Missouri",
np.where(df_csci["What state/country were you born in?"] == "Mexico", "Mexico",
np.where(df_csci["What state/country were you born in?"] == "india", "India",
np.where(df_csci["What state/country were you born in?"] == "I was born in Chandigarh, India!", "India",
np.where(df_csci["What state/country were you born in?"] == "People's Republic of China", "China",
np.where(df_csci["What state/country were you born in?"] == "Cameroon", "Cameroon",
np.where(df_csci["What state/country were you born in?"] == "Kazakhstah", "Kazakhstah",
np.where(df_csci["What state/country were you born in?"] == "TEXAS", "Texas",
np.where(df_csci["What state/country were you born in?"] == "Oklahoma", "Oklahoma",
np.where(df_csci["What state/country were you born in?"] == "Kansas, Overland Park", "Kansas",
np.where(df_csci["What state/country were you born in?"] == "New Jersey", "New Jersey",
np.where(df_csci["What state/country were you born in?"] == "Missouri, USA", "Missouri",
np.where(df_csci["What state/country were you born in?"] == "Saint Louis, Missouri", "Missouri",
np.where(df_csci["What state/country were you born in?"] == "Georgia(the country not the state)", "Georgia", ""))))))))))))))))
df_csci
# Out:
#                     Timestamp What is your name?  \
# 0   2024/09/05 6:10:09 PM EST               Alex
# 1   2024/09/05 6:33:51 PM EST              Tanay
# 2   2024/09/05 6:34:21 PM EST            Akshita
# 3   2024/09/05 6:35:03 PM EST            Anthony
# 4   2024/09/05 6:35:56 PM EST               Nuri
# 5   2024/09/05 6:35:57 PM EST             Mahley
# 6   2024/09/05 6:36:02 PM EST             Chetan
# 7   2024/09/05 6:36:13 PM EST             Steven
# 8   2024/09/05 6:36:14 PM EST               Nico
# 9   2024/09/05 6:36:24 PM EST             Iovane
# 10  2024/09/05 6:36:36 PM EST            Brandon
# 11  2024/09/05 6:36:48 PM EST             Carter
# 12  2024/09/05 6:37:04 PM EST              Tanav
# 13  2024/09/05 6:37:23 PM EST           Abhishek
# 14  2024/09/05 6:37:32 PM EST              Garlo
# 15  2024/09/05 6:37:33 PM EST              Vivek
# 16  2024/09/05 6:37:43 PM EST          Abhilasha
# 17  2024/09/05 6:38:14 PM EST               Tony
# ...

# %%
df_csci["How many pets and of which kind do you have?"] = np.where(df_csci["How many pets and of which kind do you have?"] == "0", "No pets",
np.where(df_csci["How many pets and of which kind do you have?"] == "1, Dog", "One Dog",
np.where(df_csci["How many pets and of which kind do you have?"] == "2 minature schnauzers", "Two mini Schnauzers",
np.where(df_csci["How many pets and of which kind do you have?"] == "three dogs", "Three Dogs",
np.where(df_csci["How many pets and of which kind do you have?"] == "no pets", "No pets",
np.where(df_csci["How many pets and of which kind do you have?"] == "had 8 dogs, not anymore", "No pets",
np.where(df_csci["How many pets and of which kind do you have?"] == "1 Cat; 6 Dogs (Over two households)", "One Cat and Six Dogs",
np.where(df_csci["How many pets and of which kind do you have?"] == "None :( But I really want a cat!", "No pets",
np.where(df_csci["How many pets and of which kind do you have?"] == "2, dogs.", "Two Dogs",
np.where(df_csci["How many pets and of which kind do you have?"] == "2 dogs", "Two Dogs",
np.where(df_csci["How many pets and of which kind do you have?"] == "2, Grumpy the exotic shorthair w heterchromia and my dog Furball is a rescue but he is just as cute", "Two Dogs",
np.where(df_csci["How many pets and of which kind do you have?"] == "1", "One Dog",
np.where(df_csci["How many pets and of which kind do you have?"] == "I have two dogs. They're bernedoodles.", "Two Dogs",
np.where(df_csci["How many pets and of which kind do you have?"] == "2 cats, one dog", "Two Cats and One Dog",
np.where(df_csci["How many pets and of which kind do you have?"] == "1 dog and 1 cat", "One Dog and One Cat",
np.where(df_csci["How many pets and of which kind do you have?"] == "none", "No pets",
np.where(df_csci["How many pets and of which kind do you have?"] == "I have two dogs and they are both at home", "Two Dogs",
np.where(df_csci["How many pets and of which kind do you have?"] == "no pets!", "No pets",
np.where(df_csci["How many pets and of which kind do you have?"] == "No pets", "No pets",""
)))))))))))))))))))
df_csci
# Out:
#                     Timestamp What is your name?  \
# 0   2024/09/05 6:10:09 PM EST               Alex
# 1   2024/09/05 6:33:51 PM EST              Tanay
# 2   2024/09/05 6:34:21 PM EST            Akshita
# 3   2024/09/05 6:35:03 PM EST            Anthony
# 4   2024/09/05 6:35:56 PM EST               Nuri
# 5   2024/09/05 6:35:57 PM EST             Mahley
# 6   2024/09/05 6:36:02 PM EST             Chetan
# 7   2024/09/05 6:36:13 PM EST             Steven
# 8   2024/09/05 6:36:14 PM EST               Nico
# 9   2024/09/05 6:36:24 PM EST             Iovane
# 10  2024/09/05 6:36:36 PM EST            Brandon
# 11  2024/09/05 6:36:48 PM EST             Carter
# 12  2024/09/05 6:37:04 PM EST              Tanav
# 13  2024/09/05 6:37:23 PM EST           Abhishek
# 14  2024/09/05 6:37:32 PM EST              Garlo
# 15  2024/09/05 6:37:33 PM EST              Vivek
# 16  2024/09/05 6:37:43 PM EST          Abhilasha
# 17  2024/09/05 6:38:14 PM EST               Tony
# ...

# %%
df_csci["What is your favorite type of food?"] = np.where(df_csci["What is your favorite type of food?"] == "Italian", "Italian",
np.where(df_csci["What is your favorite type of food?"] == "Japanese", "Japanese",
np.where(df_csci["What is your favorite type of food?"] == "Mexican", "Mexican",
np.where(df_csci["What is your favorite type of food?"] == "American", "Not a real thing",
np.where(df_csci["What is your favorite type of food?"] == "Indian", "Indian",
np.where(df_csci["What is your favorite type of food?"] == "Chinese", "Chinese",
np.where(df_csci["What is your favorite type of food?"] == "all of the above", "All of the above",
np.where(df_csci["What is your favorite type of food?"] == "korean", "Korean", ""))))))))
df_csci

# %%
df_csci["What is your major?"] = np.where(df_csci["What is your major?"] == "Computer Science", "Computer Science",
np.where(df_csci["What is your major?"] == "Data Science", "Data Science",
np.where(df_csci["What is your major?"] == "CS/Business", "Computer Science and Business",
np.where(df_csci["What is your major?"] == "Business Economics", "Business and Economics",
np.where(df_csci["What is your major?"] == "computer science", "Computer Science",
np.where(df_csci["What is your major?"] == "cs/ finance", "Computer Science and Finance",
np.where(df_csci["What is your major?"] == "Computer Science; considering an additional major or a minor", "Computer Science",
np.where(df_csci["What is your major?"] == "comp sci", "Computer Science",
np.where(df_csci["What is your major?"] == "Biology w/ evolutionary bio minor", "Biology",
np.where(df_csci["What is your major?"] == "Data science", "Data Science",
np.where(df_csci["What is your major?"] == "Computer Science, B.A. (I might switch to B.S., but I wish to pursue a career in digital IP law, eventually!)", "Computer Science",
np.where(df_csci["What is your major?"] == "TBD", "Not Decided",
np.where(df_csci["What is your major?"] == "computer science", "Computer Science",
np.where(df_csci["What is your major?"] == "Computer science", "Computer Science",
np.where(df_csci["What is your major?"] == "Economics", "Economics","")))))))))))))))
df_csci

# %%
df_csci["How old are you?"] = np.where(df_csci["How old are you?"] == "18", "New Adult",
np.where(df_csci["How old are you?"] == "19", "Adult Plus One Year",
np.where(df_csci["How old are you?"] == "21", "Adult Plus Three Years",
np.where(df_csci["How old are you?"] == "20", "Adult Plus Two Years",
np.where(df_csci["How old are you?"] == "17", "Adult Minus One Year","")))))
df_csci
# Out:
#                     Timestamp What is your name?  \
# 0   2024/09/05 6:10:09 PM EST               Alex
# 1   2024/09/05 6:33:51 PM EST              Tanay
# 2   2024/09/05 6:34:21 PM EST            Akshita
# 3   2024/09/05 6:35:03 PM EST            Anthony
# 4   2024/09/05 6:35:56 PM EST               Nuri
# 5   2024/09/05 6:35:57 PM EST             Mahley
# 6   2024/09/05 6:36:02 PM EST             Chetan
# 7   2024/09/05 6:36:13 PM EST             Steven
# 8   2024/09/05 6:36:14 PM EST               Nico
# 9   2024/09/05 6:36:24 PM EST             Iovane
# 10  2024/09/05 6:36:36 PM EST            Brandon
# 11  2024/09/05 6:36:48 PM EST             Carter
# 12  2024/09/05 6:37:04 PM EST              Tanav
# 13  2024/09/05 6:37:23 PM EST           Abhishek
# 14  2024/09/05 6:37:32 PM EST              Garlo
# 15  2024/09/05 6:37:33 PM EST              Vivek
# 16  2024/09/05 6:37:43 PM EST          Abhilasha
# 17  2024/09/05 6:38:14 PM EST               Tony
# ...

# %%
df_csci["How old are you?"].value_counts()
# Out:
# How old are you?
#     26
# Name: count, dtype: int64

# %%
n, bins, patches = plt.hist(x = df_csci["How many siblings do you have?"], bins = "auto")
plt.xlabel("How many siblings do you have?")
plt.ylabel("Frequency")
plt.title("Sibling Frequency Histogram")
# Out:
# Text(0.5, 1.0, 'Sibling Frequency Histogram')

# %%
pro_gender = df_csci.groupby("What are your pronouns?").count()
pro_gender
colors = ["blue", "pink", "green"]
pro_gender.plot(kind = "pie", y = "What class are you in? ", colors = colors)
plt.title("Pie Chart of Gender in CSCI_1070")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Gender in CSCI_1070')

# %%
plt.plot(df_csci["How much experience do you have programming?"], df_csci["How old are you?"], ".")
plt.title("Experience to Age Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Experience to Age Scatter Plot')

# %%
n, bins, patches = plt.hist(x = df_csci["Whats your favorite bash command?"], bins = "auto")
plt.xlabel("Whats your favorite bash command?")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
bash_com = df_csci.groupby("What is your favorite type of food?").count()
colors = ["Red", "Yellow"]
bash_com.plot(kind = "pie", y = "What is your name?", colors = colors)
plt.title("Pie Chart of Ethnicity")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Ethnicity')
